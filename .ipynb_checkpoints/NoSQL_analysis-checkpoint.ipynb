# %% [markdown]
# # Eat Safe, Love – NoSQL Analysis

# %% [markdown]
# ## Part 3 – Exploratory Analysis
#
# _Eat Safe, Love_ has specific questions they want answered, which will help them find the locations they wish to visit and avoid.
#
# Some notes to be aware of during our exploratory analysis:
#
# - `RatingValue` refers to the overall rating decided by the Food Authority and ranges from 1-5. The higher the value, the better the rating.
#     - **Note:** This field also includes non-numeric values such as 'Pass', where 'Pass' means that the establishment passed their inspection but isn't given a number rating. We will coerce non-numeric values to nulls during the database setup before converting ratings to integers.
# - The scores for Hygiene, Structural, and ConfidenceInManagement work in reverse. This means, the higher the value, the worse the establishment is in these areas.
#
# Use the following questions to explore the database, and find the answers to provide the magazine editors. Unless otherwise stated, for each question:
# - Use `count_documents` to display the number of documents contained in the result.
# - Display the first document in the results using `pprint`.
# - Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %%
# load dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# create an instnce of MongoClient
mongo = MongoClient(port=27017)

# confirm that the new database was instantiated
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food')

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']
establishments
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food'), 'establishments')

# %% [markdown]
# #### 1. Which establishments have a hygiene score equal to 20?

# %%
# design a query to find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}
results = establishments.find(query)

# use count_documents to display the number of documents in the result
print(f"""
There are {establishments.count_documents(query)} establishments in the collection with a hygiene score of 20.

""")

# display the first document in the results using pprint
pprint(results[0])
# Out:
# There are 41 establishments in the collection with a hygiene score of 20.
#
#
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6455f2b1d234f5d10142c01c'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
# convert the result to a `pandas` dataframe
results_hyg20_df = pd.DataFrame(results)

# display the number of rows in the dataframe
print(f"""
There are {len(results_hyg20_df)} rows in the DataFrame.

""")

# display the first 10 rows of the dataframe
results_hyg20_df.head(10)
# Out:
# There are 41 rows in the DataFrame.
#                         _id   FHRSID  ChangesByServerID  \
# 0  6455f2b1d234f5d10142c01c   110681                  0
# 1  6455f2b1d234f5d10142c38f   612039                  0
# 2  6455f2b2d234f5d10142c69a   730933                  0
# 3  6455f2b2d234f5d10142c88c   172735                  0
# 4  6455f2b2d234f5d10142c899   172953                  0
# 5  6455f2b2d234f5d10142d248   512854                  0
# 6  6455f2b2d234f5d10142d457  1537089                  0
# 7  6455f2b2d234f5d10142e983   155648                  0
# 8  6455f2b2d234f5d10142edd1  1012883                  0
# 9  6455f2b2d234f5d10142f5df   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# #### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# design a query to find the establishments with London as the Local Authority
# and has a RatingValue greater than or equal to 4
query = {'LocalAuthorityName': {'$regex': 'London'},
         'RatingValue': {'$gte': 4}}
results = establishments.find(query)

# use count_documents to display the number of documents in the result
print(f"""
There are {establishments.count_documents(query)} establishments in the collection with London as
the Local Authority and with a Rating Value greater than or equal to 4.

""")

# display the first document in the results using pprint
pprint(results[0])
# Out:
# There are 33 establishments in the collection with London as
# the Local Authority and with a Rating Value greater than or equal to 4.
#
#
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
# ...

# %%
# convert the result to a Pandas DataFrame
results_rv4up_df = pd.DataFrame(results)

# display the number of rows in the DataFrame
print(f"""
There are {len(results_rv4up_df)} rows in the DataFrame.

""")

# display the first 10 rows of the DataFrame
results_rv4up_df.head(10)
# Out:
# There are 33 rows in the DataFrame.
#                         _id   FHRSID  ChangesByServerID  \
# 0  6455f2b2d234f5d10142da30   621707                  0
# 1  6455f2b2d234f5d10142dd53  1130836                  0
# 2  6455f2b2d234f5d10142e8a0   293783                  0
# 3  6455f2b2d234f5d10142f69f   294474                  0
# 4  6455f2b2d234f5d10142f6a2  1315095                  0
# 5  6455f2b2d234f5d10142fda5   294900                  0
# 6  6455f2b3d234f5d101431eb6   293756                  0
# 7  6455f2b3d234f5d101432284   878523                  0
# 8  6455f2b3d234f5d101432294   293772                  0
# 9  6455f2b3d234f5d10143229a   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# #### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# search within 0.01 degree on either side of the latitude and longitude.
# rating value must equal 5
# sort by hygiene score

degree_search = 0.01
latitude = float(establishments.find_one({'BusinessName': 'Penang Flavours'})['geocode']['latitude'])
longitude = float(establishments.find_one({'BusinessName': 'Penang Flavours'})['geocode']['longitude'])

query = {'geocode.latitude': {'$lte': latitude + degree_search,
                              '$gte': latitude - degree_search},
         'geocode.longitude': {'$lte': longitude + degree_search,
                               '$gte': longitude - degree_search},
         'RatingValue': 5
        }

sort =  [('scores.Hygiene', 1)]

results = establishments.find(query).sort(sort).limit(5)
print(results)

# %%
# convert result to `pandas` DataFrame
results_closerv5_df = pd.DataFrame(results)
results_closerv5_df
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  6455f2b2d234f5d101431854  1380578                  0
# 1  6455f2b2d234f5d101431889   694478                  0
# 2  6455f2b2d234f5d101431888   695241                  0
# 3  6455f2b2d234f5d101431840   695223                  0
# 4  6455f2b2d234f5d101431871   694609                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0                    14425  Howe and Co Fish and Chips - Van 17
# 1             PI/000086506                    Atlantic Fish Bar
# 2             PI/000179088              Plumstead Manor Nursery
# 3             PI/000178842                              Iceland
# 4             PI/000116619                            Volunteer
#
#                             BusinessType  BusinessTypeID  \
# 0                         Mobile caterer            7846
# 1                 Takeaway/sandwich shop            7844
# 2                        Caring Premises               5
# ...

# %% [markdown]
# #### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# create a pipeline that: 
# 1 – matches establishments with a hygiene score of 0
match_query = {'$match': {'scores.Hygiene': 0}
              }

# 2 – groups the matches by Local Authority
group_query = {'$group': {'_id': '$LocalAuthorityName', 'count': {'$sum': 1}
                         }
              }

# 3 – sorts the matches from highest to lowest
sort_specs = {'$sort': {'count': -1}
             }

pipeline = [match_query, group_query, sort_specs]
results = list(establishments.aggregate(pipeline))

# print the number of documents in the result
print("Number of establishments in result: ", len(results), '\n')

# print the first 10 results
pprint(results[0:10])
# Out:
# Number of establishments in result:  55
#
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# convert the result to a `pandas` DataFrame
results_hyg0_df = pd.DataFrame(results)

# display the number of rows in the DataFrame
print(f"""
There are {len(results_hyg0_df)} rows in the DataFrame.

""")

# Display the first 10 rows of the DataFrame
results_hyg0_df.head(10)
# Out:
# There are 55 rows in the DataFrame.
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
